# %% [markdown]
# # Importing the Necessary Libraries
#
# Pandas is required for modifying the dataframes and csv files. Shuffle from sklearn is important to shuffle the dataset so it's more "random". train_test_split is used to split the dataset into training, validation and test sets. os is used to then remove the temporary, intermediate files at the end.

# %%
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import os

# %%
fake_news = pd.read_csv('../BaseDataset/fake_news.csv')
real_news = pd.read_csv('../BaseDataset/real_news.csv')

# %%
fake_news = shuffle(fake_news, random_state=42)
real_news = shuffle(real_news, random_state=42)

# %%
fake_news
# Out:
#                                                    title  \
# 12907  watch: trump defends russia, so john mccain ha...
# 12408  donald trump’s new campaign slogan is literall...
# 196    over 500 russian and egyptian troops train to ...
# 24255  gop presidential candidate marco rubio casts d...
# 15387  bruce campbell shatters bloodied ‘trump suppor...
# ...                                                  ...
# 21575  leaked: hillary drunk in the afternoon…needs t...
# 5390           how safe is food packaging to our health?
# 860    amazing meditative session right here about wh...
# 15795  republicans assault the poor with a new plan t...
# 23654  holy freedom of speech! obama’s attorney gener...
#
#                                                     text  label
# 12907  donald trump is vladimir putin s puppet, so of...      1
# 12408  seriously, he really picked this as his 2020 s...      1
# 196    media skeptic over 500 russian and egyptian tr...      1
# 24255  one more republican doing his part to aid obam...      1
# 15387  while it s usually donald trump s fans that ma...      1
# ...                                                  ...    ...
# 21575  an aug. 8, 2015, email exchange between clinto...      1
# 5390   keywords: food packaging , packaging one of th...      1
# 860    amazing meditative session right here about wh...      1
# 15795  paul ryan and the republican leadership are ro...      1
# 23654  update: a leading supreme court analyst thinks...      1
#
# [26601 rows x 3 columns]

# %%
real_news
# Out:
#                                                    title  \
# 15961  in trump's ohio bastion, supporters dismiss up...
# 14652  trump discusses immigration ideas in dinner wi...
# 10021  for those keeping score, american women domina...
# 14552  u.s. small-cap firms look to spend tax savings...
# 6612   why land and homes actually tend to be disappo...
# ...                                                  ...
# 16850  trump: special counsel appointment 'hurts our ...
# 6265   scarborough: 9th circuit ruling is ’laughable,...
# 11284         trump, rnc announce joint fundraising deal
# 860    racist note that led to protests, cancelled cl...
# 15795  man whose firm was behind trump dossier won't ...
#
#                                                     text  label
# 15961  little hocking, ohio (reuters) - while revelat...      0
# 14652  washington (reuters) - president donald trump ...      0
# 10021  rio de janeiro — the very idea of a medal coun...      0
# 14552  new york (reuters) - a texas-based chain of st...      0
# 6612   buy land: they’re not making it anymore. that ...      0
# ...                                                  ...    ...
# 16850  washington (reuters) - president donald trump ...      0
# 6265   friday on msnbc’s “morning joe,” host joe scar...      0
# 11284  the move will help trump consolidate the repub...      0
# 860    administrators at st. olaf’s college revealed ...      0
# 15795  washington (reuters) - the co-founder of the f...      0
#
# [34199 rows x 3 columns]

# %%
combined_news = pd.concat([fake_news, real_news])

# %%
combined_news.to_csv('combined.csv', index=False)

# %%
combined_news = pd.read_csv('combined.csv')

# %% [markdown]
# # Creating the Train, Test and Validation Sets
#
# The 80-20 split is pedagogically the best split but since we also have to create an additional validation set, it will technically be 80-10-10. This split is being done through train_test_split. It is paramount that if one instance of fake news appears in the training set, it doesn't appear in the validation and test set. This is to ensure that both the validation and test sets are truly "unseen" data in comparison to the training set but is still representative of the type of data that will be encountered by the model. The same holds for any data that appears in the validation and test set. The data has to be truly unique in terms of occurrence. Additional check to ensure this will be undertaken in the coming sections.

# %%
# Add a unique identifier column to combined_news DataFrame
combined_news['unique_id'] = range(len(combined_news))

# Define the percentages for splitting
train_percent = 0.8

# Group the data by the 'label' column
grouped = combined_news.groupby('label')

# Initialize empty DataFrames for train, validation, and test sets
train_data = pd.DataFrame(columns=combined_news.columns)
val_data = pd.DataFrame(columns=combined_news.columns)
test_data = pd.DataFrame(columns=combined_news.columns)

# Iterate over each label group
for label, group in grouped:
    # Split the group into train and remaining data
    train, remaining = train_test_split(group, train_size=train_percent, 
                                        random_state=42)
    
    # Split the remaining data into validation and test sets
    val, test = train_test_split(remaining, test_size=0.5, random_state=42)
    
    # Append the splits to the respective DataFrames
    train_data = pd.concat([train_data, train])
    val_data = pd.concat([val_data, val])
    test_data = pd.concat([test_data, test])

# Reset the indices for the DataFrames
train_data.reset_index(drop=True, inplace=True)
val_data.reset_index(drop=True, inplace=True)
test_data.reset_index(drop=True, inplace=True)

# Save datasets to CSV files
train_data.to_csv('train.csv', index=False)
val_data.to_csv('val.csv', index=False)
test_data.to_csv('test.csv', index=False)

# Save datasets to CSV files in BaseDataset, to be used for other Linguistic Feature Calculations
train_data.to_csv('../BaseDataset/train.csv', index=False)
val_data.to_csv('../BaseDataset/val.csv', index=False)
test_data.to_csv('../BaseDataset/test.csv', index=False)

# %%
train_data
# Out:
#                                                    title  \
# 0      iranian general, assad discuss joint military ...
# 1      top u.s. official visits vietnam to assess hum...
# 2      senators want probe of allergan transfer deal ...
# 3      will the comey bombshell really shake up the 2...
# 4      egypt election in view, sisi supporters fire u...
# ...                                                  ...
# 48634  loretta lynch makes disturbing video encouragi...
# 48635  come on down to hole-suckers on southside and ...
# 48636                                please make it stop
# 48637  report: trump’s mind shattered in the face of ...
# 48638  candace cameron bure dishes on the main conser...
#
#                                                     text label unique_id
# 0      beirut (reuters) - iran s military chief met w...     0     27401
# 1      hanoi (reuters) - a top u.s. envoy began a two...     0     41572
# 2      (reuters) - four u.s. senators have asked the ...     0     54822
# 3      first read is a morning briefing from meet the...     0     26745
# 4      cairo (reuters) - six months before egypt s el...     0     42204
# ...                                                  ...   ...       ...
# 48634  obama s former ag loretta lynch released a vid...     1     21575
# 48635  come on down to hole-suckers on southside and ...     1      5390
# 48636  posted on november 7, 2016 by walter brasch wi...     1       860
# 48637  going into election day, trump s campaign is w...     1     15795
# 48638  getty - tibrina hobson candace cameron bure ha...     1     23654
#
# [48639 rows x 4 columns]

# %%
train_data.value_counts("label")
# Out:
# label
# 0    27359
# 1    21280
# dtype: int64

# %%
val_data
# Out:
#                                                   title  \
# 0     u.s. allied syrian groups form civilian counci...
# 1     ga congressional dem candidate ossoff: not an ...
# 2     u.s. lawmakers ask trump to turn over any come...
# 3     meeting between bill clinton and loretta lynch...
# 4     merkel, bavaria allies agree on migrant policy...
# ...                                                 ...
# 6075  oops: donald trump’s debate guest supports ter...
# 6076  spot on! fox sports host calls out espn’s libe...
# 6077  obama commencement speech to black graduates: ...
# 6078  comment on europe’s forgotten ‘hitler’ killed ...
# 6079  chaos breaks out after illegal alien townhall ...
#
#                                                    text label unique_id
# 0     deir al zor, syria (reuters) - u.s.-allied mil...     0     36938
# 1     dem. candidate for georgia congressional seat ...     0     40217
# 2     washington (reuters) - u.s. lawmakers on sunda...     0     52849
# 3     washington — an airport encounter this week be...     0     51808
# 4     berlin (reuters) - german chancellor angela me...     0     33337
# ...                                                 ...   ...       ...
# 6075  this lack of oversight proves that donald trum...     1       139
# 6076  tucker carlson responded to an espn anchor cal...     1     11500
# 6077  because getting something for nothing is all t...     1     13781
# 6078  black emanuelle fixed all that in 1976. attila...     1      3328
# 6079  chaos broke out after legal americans and ille...     1      7542
#
# [6080 rows x 4 columns]

# %%
val_data.value_counts("label")
# Out:
# label
# 0    3420
# 1    2660
# dtype: int64

# %%
test_data
# Out:
#                                                   title  \
# 0     hypothetically speaking, u.s. admiral says rea...
# 1     south africa's anc says party officials barred...
# 2     seattle judge says trump travel ban case shoul...
# 3     outspoken lieutenant general named trump's top...
# 4     trump calls for worldwide action against north...
# ...                                                 ...
# 6076  watch: wolf blitzer silences trump supporter’s...
# 6077  mass nye sexual assaults in europe explained: ...
# 6078  pro abortion pac, emily’s list doing its part ...
# 6079  trump raises concern over members of urban com...
# 6080  wow! hillary clinton wants new york, florida a...
#
#                                                    text label unique_id
# 0     melbourne (reuters) - the u.s. pacific fleet c...     0     55612
# 1     johannesburg (reuters) - south africa s africa...     0     55993
# 2     seattle (reuters) - a u.s. federal judge on mo...     0     58277
# 3     west palm beach, fla./washington (reuters) - u...     0     52137
# 4     seoul (reuters) - u.s. president donald trump ...     0     47382
# ...                                                 ...   ...       ...
# 6076  trump campaign manager kellyanne conway ran in...     1     21903
# 6077  this is possibly the most disturbing video we ...     1      7363
# 6078  of course emily s list is going to support hil...     1     22076
# 6079  nation puts 2016 election into perspective by ...     1     21417
# 6080  hillary clinton just opened her mouth and prov...     1     12796
#
# [6081 rows x 4 columns]

# %%
test_data.value_counts("label")
# Out:
# label
# 0    3420
# 1    2661
# dtype: int64

# %%
# Load the CSV files into DataFrames
train_data = pd.read_csv('train.csv')
val_data = pd.read_csv('val.csv')
test_data = pd.read_csv('test.csv')

# Get unique IDs for each dataset
train_unique_ids = set(train_data['unique_id'])
val_unique_ids = set(val_data['unique_id'])
test_unique_ids = set(test_data['unique_id'])

# Find unique IDs in train not in val or test
train_not_in_val = train_unique_ids - val_unique_ids
train_not_in_test = train_unique_ids - test_unique_ids

# Find unique IDs in val not in train or test
val_not_in_train = val_unique_ids - train_unique_ids
val_not_in_test = val_unique_ids - test_unique_ids

# Find unique IDs in test not in train or val
test_not_in_train = test_unique_ids - train_unique_ids
test_not_in_val = test_unique_ids - val_unique_ids

print(f"Rows in train_data: {len(train_data)}")
print(f"Rows in train_data not in val_data: {len(train_not_in_val)}")
print(f"Rows in train_data not in test_data: {len(train_not_in_test)}")
print("")

print(f"Rows in train_data: {len(val_data)}")
print(f"Rows in val_data not in train_data: {len(val_not_in_train)}")
print(f"Rows in val_data not in test_data: {len(val_not_in_test)}")
print("")

print(f"Rows in test_data: {len(test_data)}")
print(f"Rows in test_data not in train_data: {len(test_not_in_train)}")
print(f"Rows in test_data not in val_data: {len(test_not_in_val)}")
# Out:
# Rows in train_data: 48639
# Rows in train_data not in val_data: 48639
# Rows in train_data not in test_data: 48639
#
# Rows in train_data: 6080
# Rows in val_data not in train_data: 6080
# Rows in val_data not in test_data: 6080
#
# Rows in test_data: 6081
# Rows in test_data not in train_data: 6081
# Rows in test_data not in val_data: 6081

# %%
os.remove("combined.csv")
