# %%
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import os

import re
from collections import Counter
import liwc
import spacy
import spacy_transformers
import swifter
import string

# %%
# Load the datasets
train_data = pd.read_csv('../BaseDataset/train.csv')
val_data = pd.read_csv('../BaseDataset/val.csv')
test_data = pd.read_csv('../BaseDataset/test.csv')

# %%
#Uncomment this code if it's your first time running this code

#pip install en_core_web_md-3.7.1-py3-none-any.whl

# %%
# Load the spaCy English model
#nlp = spacy.load("en_core_web_trf")

nlp = spacy.load("en_core_web_md")

# %%
#Function designed to remove excess whitespaces and numbers. This is to ensure that the tokenize function only counts words.
#Numbers do not count towards words as they do not have any associated linguistic features.
def preprocess_text(text):

    # Characters to keep
    characters_to_keep = '.?'

    # Additional characters to remove
    additional_characters_to_remove = '‘’“”|@#$%^&*(;:),{<>}"[\/]+-=_~`'

    # Create a translator to remove specified characters
    translator = str.maketrans('', '', ''.join(set(string.punctuation) - set(characters_to_keep)) + additional_characters_to_remove)
    
    # Apply the translation to the text
    text = text.translate(translator)
    
    # Remove numbers
    text = re.sub(r'\b\d+\b', '', text)

    # Remove excess whitespaces
    text = ' '.join(text.split())

    return text

# %% [markdown]
# ### Tokenizer without Spacy
# def tokenize(text):
#     for match in re.finditer(r'\w+', text, re.UNICODE):
#         yield match.group(0)

# %%
#Tokenizer to only count words, not punctuations. This for accurate word counting. We're is counted equivalently to We Are.
def tokenize(text):
    doc = nlp(text)
    return [token.text for token in doc]

# %%
text = " seattle (reuters) - a u.s. federal judge on monday said courtroom proceedings over president donald trump’s travel ban should continue in seattle during an ongoing appeals court review. at a hearing, u.s. district judge james robart in seattle said he was not prepared to slow down the case. robart directed attorneys for the u.s. justice department and washington state’s attorney general to prepare for further proceedings in seattle."
text = preprocess_text(text)
print(text)
# Out:
# seattle reuters a u.s. federal judge on monday said courtroom proceedings over president donald trumps travel ban should continue in seattle during an ongoing appeals court review. at a hearing u.s. district judge james robart in seattle said he was not prepared to slow down the case. robart directed attorneys for the u.s. justice department and washington states attorney general to prepare for further proceedings in seattle.

# %%
parse, category_names = liwc.load_token_parser('LIWC2007_English100131.dic')

# %%
#Linguistic Features based on Hancock and Woodworth
def calculate_linguistic_features(text):
    text = preprocess_text(text)
    doc = nlp(text)
    total_words = len(tokenize(text))
    total_sentences = len(list(doc.sents))

    # List of first person singular, second person, and third person pronouns
    first_person_singular_words = ["i", "me", "my", "mine"]
    second_person_words = ["you", "your", "yours", "yourself"]
    third_person_words = ["he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves"]

    # Initialize counts
    first_person_singular_count = 0
    second_person_count = 0
    third_person_count = 0

    # Count occurrences of pronouns and other linguistic features
    text_tokens = tokenize(text)
    token_counts = Counter(category for token in text_tokens for category in parse(token))

    for token in doc:
        if token.lower_ in first_person_singular_words:
            first_person_singular_count += 1
        elif token.lower_ in second_person_words:
            second_person_count += 1
        elif token.lower_ in third_person_words:
            third_person_count += 1

    # Retrieve counts from the LIWC dictionary
    negation_count = token_counts['negate']
    exclusive_count = token_counts['excl']
    causation_count = token_counts['cause']
    senses_count = token_counts['percept'] + token_counts['see'] + token_counts['hear'] + token_counts['feel']

    return {
        'Words_per_Sentence': total_words / total_sentences if total_sentences > 0 else 0,
        'Percentage_Questions': (len([sent.text for sent in doc.sents if '?' in sent.text]) / total_sentences) * 100 if total_sentences > 0 else 0,
        'Percentage_First_Person_Singular': (first_person_singular_count / total_words) * 100 if total_words > 0 else 0,
        'Percentage_Second_Person': (second_person_count / total_words) * 100 if total_words > 0 else 0,
        'Percentage_Third_Person': (third_person_count / total_words) * 100 if total_words > 0 else 0,
        'Percentage_Negation': (negation_count / total_words) * 100 if total_words > 0 else 0,
        'Percentage_Exclusive': (exclusive_count / total_words) * 100 if total_words > 0 else 0,
        'Percentage_Causation': (causation_count / total_words) * 100 if total_words > 0 else 0,
        'Percentage_Sense': (senses_count / total_words) * 100 if total_words > 0 else 0
    }

# %%
# Apply the function to val_data in parallel
val_data = pd.concat([val_data, val_data['text'].swifter.apply(calculate_linguistic_features).apply(pd.Series)], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/6080 [00:00<?, ?it/s]

# %%
val_data.to_csv('val.csv', index=False)

# %%
# Apply the function to test_data in parallel
test_data = pd.concat([test_data, test_data['text'].swifter.apply(calculate_linguistic_features).apply(pd.Series)], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/6081 [00:00<?, ?it/s]

# %%
test_data.to_csv('test.csv', index=False)

# %%
# Apply the function to train_data in parallel
train_data = pd.concat([train_data, train_data['text'].swifter.apply(calculate_linguistic_features).apply(pd.Series)], axis=1)
# Out:
# Pandas Apply:   0%|          | 0/48639 [00:00<?, ?it/s]

# %%
train_data.to_csv('train.csv', index=False)

# %%
train_data
# Out:
#                                                    title  \
# 0      iranian general, assad discuss joint military ...
# 1      top u.s. official visits vietnam to assess hum...
# 2      senators want probe of allergan transfer deal ...
# 3      will the comey bombshell really shake up the 2...
# 4      egypt election in view, sisi supporters fire u...
# ...                                                  ...
# 48634  loretta lynch makes disturbing video encouragi...
# 48635  come on down to hole-suckers on southside and ...
# 48636                                please make it stop
# 48637  report: trump’s mind shattered in the face of ...
# 48638  candace cameron bure dishes on the main conser...
#
#                                                     text  label  unique_id  \
# 0      beirut (reuters) - iran s military chief met w...      0      27401
# 1      hanoi (reuters) - a top u.s. envoy began a two...      0      41572
# 2      (reuters) - four u.s. senators have asked the ...      0      54822
# 3      first read is a morning briefing from meet the...      0      26745
# 4      cairo (reuters) - six months before egypt s el...      0      42204
# ...                                                  ...    ...        ...
# 48634  obama s former ag loretta lynch released a vid...      1      21575
# 48635  come on down to hole-suckers on southside and ...      1       5390
# 48636  posted on november 7, 2016 by walter brasch wi...      1        860
# 48637  going into election day, trump s campaign is w...      1      15795
# 48638  getty - tibrina hobson candace cameron bure ha...      1      23654
#
#        Words_per_Sentence  Percentage_Questions  \
# 0               28.777778              0.000000
# 1               32.900000              0.000000
# 2               30.416667              0.000000
# 3               21.254545              3.636364
# 4               24.444444              0.000000
# ...                   ...                   ...
# 48634           17.466667              0.000000
# 48635           23.500000              0.000000
# 48636           25.785714              0.000000
# 48637           26.809524              4.761905
# 48638           29.176471              0.000000
#
#        Percentage_First_Person_Singular  Percentage_Second_Person  \
# 0                              0.000000                  0.000000
# 1                              0.000000                  0.000000
# 2                              0.000000                  0.000000
# 3                              0.085543                  0.000000
# 4                              0.000000                  0.090909
# ...                                 ...                       ...
# 48634                          1.908397                  0.763359
# 48635                          3.723404                  2.127660
# 48636                          0.000000                  0.000000
# 48637                          0.532860                  0.177620
# 48638                          1.814516                  0.403226
#
#        Percentage_Third_Person  Percentage_Negation  Percentage_Exclusive  \
# 0                     1.930502             0.000000              0.000000
# 1                     2.735562             0.607903              1.519757
# 2                     2.191781             0.547945              0.821918
# 3                     4.790419             1.197605              1.710864
# 4                     3.181818             0.545455              1.636364
# ...                        ...                  ...                   ...
# 48634                 3.053435             0.381679              1.145038
# 48635                 1.063830             0.531915              0.531915
# 48636                 2.908587             0.415512              1.800554
# 48637                 8.703375             0.355240              1.598579
# 48638                 4.032258             1.008065              2.217742
#
#        Percentage_Causation  Percentage_Sense
# 0                  2.702703          5.405405
# 1                  1.519757          4.863222
# 2                  1.095890          6.027397
# 3                  2.138580          3.079555
# 4                  2.181818          6.181818
# ...                     ...               ...
# 48634              0.381679          3.053435
# 48635              1.063830          1.063830
# 48636              0.969529          0.831025
# 48637              1.598579          2.131439
# 48638              1.209677          2.016129
#
# [48639 rows x 13 columns]

# %%
train_data.value_counts("label")
# Out:
# label
# 0    27359
# 1    21280
# dtype: int64

# %%
val_data
# Out:
#                                                   title  \
# 0     u.s. allied syrian groups form civilian counci...
# 1     ga congressional dem candidate ossoff: not an ...
# 2     u.s. lawmakers ask trump to turn over any come...
# 3     meeting between bill clinton and loretta lynch...
# 4     merkel, bavaria allies agree on migrant policy...
# ...                                                 ...
# 6075  oops: donald trump’s debate guest supports ter...
# 6076  spot on! fox sports host calls out espn’s libe...
# 6077  obama commencement speech to black graduates: ...
# 6078  comment on europe’s forgotten ‘hitler’ killed ...
# 6079  chaos breaks out after illegal alien townhall ...
#
#                                                    text  label  unique_id  \
# 0     deir al zor, syria (reuters) - u.s.-allied mil...      0      36938
# 1     dem. candidate for georgia congressional seat ...      0      40217
# 2     washington (reuters) - u.s. lawmakers on sunda...      0      52849
# 3     washington — an airport encounter this week be...      0      51808
# 4     berlin (reuters) - german chancellor angela me...      0      33337
# ...                                                 ...    ...        ...
# 6075  this lack of oversight proves that donald trum...      1        139
# 6076  tucker carlson responded to an espn anchor cal...      1      11500
# 6077  because getting something for nothing is all t...      1      13781
# 6078  black emanuelle fixed all that in 1976. attila...      1       3328
# 6079  chaos broke out after legal americans and ille...      1       7542
#
#       Words_per_Sentence  Percentage_Questions  \
# 0              28.866667              0.000000
# 1              15.666667              0.000000
# 2              24.709677              0.000000
# 3              25.076923              0.000000
# 4              25.000000              0.000000
# ...                  ...                   ...
# 6075           56.166667             16.666667
# 6076           22.900000              0.000000
# 6077           18.095238             14.285714
# 6078           16.611354             10.043668
# 6079           28.111111             11.111111
#
#       Percentage_First_Person_Singular  Percentage_Second_Person  \
# 0                             0.000000                  0.000000
# 1                             4.787234                  0.000000
# 2                             0.000000                  0.261097
# 3                             1.380368                  0.153374
# 4                             0.000000                  0.000000
# ...                                ...                       ...
# 6075                          0.296736                  0.000000
# 6076                          0.000000                  0.000000
# 6077                          1.842105                  3.684211
# 6078                          1.156677                  2.576236
# 6079                          0.988142                  0.592885
#
#       Percentage_Third_Person  Percentage_Negation  Percentage_Exclusive  \
# 0                    2.078522             0.000000              0.461894
# 1                    5.851064             1.063830              1.595745
# 2                    1.958225             1.174935              2.349869
# 3                    4.447853             0.613497              1.380368
# 4                    2.000000             0.000000              1.000000
# ...                       ...                  ...                   ...
# 6075                 4.154303             1.186944              1.186944
# 6076                 2.183406             0.436681              0.873362
# 6077                 5.263158             1.052632              2.105263
# 6078                 2.970557             1.445846              2.602524
# 6079                 4.743083             1.185771              1.185771
#
#       Percentage_Causation  Percentage_Sense
# 0                 2.078522          1.154734
# 1                 0.000000          0.000000
# 2                 1.044386          6.527415
# 3                 1.533742          5.674847
# 4                 2.000000          2.000000
# ...                    ...               ...
# 6075              0.593472          5.341246
# 6076              0.000000          5.240175
# 6077              1.315789          5.789474
# 6078              1.393270          2.628812
# 6079              1.383399          4.743083
#
# [6080 rows x 13 columns]

# %%
val_data.value_counts("label")
# Out:
# label
# 0    3420
# 1    2660
# dtype: int64

# %%
test_data
# Out:
#                                                   title  \
# 0     hypothetically speaking, u.s. admiral says rea...
# 1     south africa's anc says party officials barred...
# 2     seattle judge says trump travel ban case shoul...
# 3     outspoken lieutenant general named trump's top...
# 4     trump calls for worldwide action against north...
# ...                                                 ...
# 6076  watch: wolf blitzer silences trump supporter’s...
# 6077  mass nye sexual assaults in europe explained: ...
# 6078  pro abortion pac, emily’s list doing its part ...
# 6079  trump raises concern over members of urban com...
# 6080  wow! hillary clinton wants new york, florida a...
#
#                                                    text  label  unique_id  \
# 0     melbourne (reuters) - the u.s. pacific fleet c...      0      55612
# 1     johannesburg (reuters) - south africa s africa...      0      55993
# 2     seattle (reuters) - a u.s. federal judge on mo...      0      58277
# 3     west palm beach, fla./washington (reuters) - u...      0      52137
# 4     seoul (reuters) - u.s. president donald trump ...      0      47382
# ...                                                 ...    ...        ...
# 6076  trump campaign manager kellyanne conway ran in...      1      21903
# 6077  this is possibly the most disturbing video we ...      1       7363
# 6078  of course emily s list is going to support hil...      1      22076
# 6079  nation puts 2016 election into perspective by ...      1      21417
# 6080  hillary clinton just opened her mouth and prov...      1      12796
#
#       Words_per_Sentence  Percentage_Questions  \
# 0              25.066667              0.000000
# 1              23.333333              0.000000
# 2              24.333333              0.000000
# 3              27.466667              0.000000
# 4              40.666667              0.000000
# ...                  ...                   ...
# 6076           26.708333              8.333333
# 6077           32.700000              0.000000
# 6078           25.600000              0.000000
# 6079           63.000000              0.000000
# 6080           17.125000             25.000000
#
#       Percentage_First_Person_Singular  Percentage_Second_Person  \
# 0                             0.000000                  0.265957
# 1                             0.000000                  0.000000
# 2                             0.000000                  0.000000
# 3                             0.404531                  0.242718
# 4                             0.000000                  0.000000
# ...                                ...                       ...
# 6076                          0.468019                  0.624025
# 6077                          0.000000                  0.000000
# 6078                          0.000000                  0.000000
# 6079                          0.000000                  0.000000
# 6080                          0.729927                  0.000000
#
#       Percentage_Third_Person  Percentage_Negation  Percentage_Exclusive  \
# 0                    2.393617             0.000000              1.595745
# 1                    2.857143             2.857143              2.857143
# 2                    1.369863             1.369863              1.369863
# 3                    3.559871             0.485437              0.566343
# 4                    3.278689             0.000000              0.819672
# ...                       ...                  ...                   ...
# 6076                 4.680187             0.936037              2.184087
# 6077                 1.834862             0.000000              0.305810
# 6078                 4.427083             0.520833              0.781250
# 6079                 5.555556             0.000000              2.777778
# 6080                 8.029197             0.729927              5.109489
#
#       Percentage_Causation  Percentage_Sense
# 0                 2.393617          7.446809
# 1                 2.142857          2.857143
# 2                 0.000000          8.219178
# 3                 1.779935          3.478964
# 4                 3.278689          6.557377
# ...                    ...               ...
# 6076              1.560062          1.872075
# 6077              0.000000          4.587156
# 6078              3.125000          2.083333
# 6079              0.793651          2.380952
# 6080              2.919708          5.109489
#
# [6081 rows x 13 columns]

# %%
test_data.value_counts("label")
# Out:
# label
# 0    3420
# 1    2661
# dtype: int64

# %%
# Load the CSV files into DataFrames
train_data = pd.read_csv('train.csv')
val_data = pd.read_csv('val.csv')
test_data = pd.read_csv('test.csv')

# Get unique IDs for each dataset
train_unique_ids = set(train_data['unique_id'])
val_unique_ids = set(val_data['unique_id'])
test_unique_ids = set(test_data['unique_id'])

# Find unique IDs in train not in val or test
train_not_in_val = train_unique_ids - val_unique_ids
train_not_in_test = train_unique_ids - test_unique_ids

# Find unique IDs in val not in train or test
val_not_in_train = val_unique_ids - train_unique_ids
val_not_in_test = val_unique_ids - test_unique_ids

# Find unique IDs in test not in train or val
test_not_in_train = test_unique_ids - train_unique_ids
test_not_in_val = test_unique_ids - val_unique_ids

print(f"Rows in train_data: {len(train_data)}")
print(f"Rows in train_data not in val_data: {len(train_not_in_val)}")
print(f"Rows in train_data not in test_data: {len(train_not_in_test)}")
print("")

print(f"Rows in train_data: {len(val_data)}")
print(f"Rows in val_data not in train_data: {len(val_not_in_train)}")
print(f"Rows in val_data not in test_data: {len(val_not_in_test)}")
print("")

print(f"Rows in test_data: {len(test_data)}")
print(f"Rows in test_data not in train_data: {len(test_not_in_train)}")
print(f"Rows in test_data not in val_data: {len(test_not_in_val)}")
# Out:
# Rows in train_data: 48639
# Rows in train_data not in val_data: 48639
# Rows in train_data not in test_data: 48639
#
# Rows in train_data: 6080
# Rows in val_data not in train_data: 6080
# Rows in val_data not in test_data: 6080
#
# Rows in test_data: 6081
# Rows in test_data not in train_data: 6081
# Rows in test_data not in val_data: 6081
