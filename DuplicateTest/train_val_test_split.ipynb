# %% [markdown]
# # Importing the Necessary Libraries
#
# Pandas is required for modifying the dataframes and csv files. Shuffle from sklearn is important to shuffle the dataset so it's more "random". train_test_split is used to split the dataset into training, validation and test sets. os is used to then remove the temporary, intermediate files at the end.

# %%
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import os

# %%
fake_news = pd.read_csv('fake_news.csv')
real_news = pd.read_csv('real_news.csv')

# %%
fake_news = shuffle(fake_news, random_state=42)
real_news = shuffle(real_news, random_state=42)

# %%
fake_news
# Out:
#                                                    title  \
# 23962  Iceland Election: Pirate Party prepares for ma...
# 4984   When Obama Admin Went After Banks, It Forced T...
# 34975  ANTI-HILLARY HALLOWEEN HOUSE Gets Violent Thre...
# 8944   HILLARY IS FURIOUS OVER EMAIL HACKS…Openly Thr...
# 441     This University Will Punish You For Being Rap...
# ...                                                  ...
# 16850  US Coalition Airstrike on Syrian Army in Al-Ta...
# 6265   HUD OFFICIAL Spends $366,000 in Fed Funds on B...
# 11284  CONGRESS JUST DEALT A BIG BLOW To Obama And Hi...
# 860    TUCKER CARLSON Exposes Radical Middle School T...
# 15795  ILLEGAL ALIENS WHO LIED TO COURT, USED FAKE SS...
#
#                                                     text  label
# 23962  Click Here To Learn More About Alexandra's Per...      1
# 4984   Share on Twitter \nA new study shows that afte...      1
# 34975                                           Via: TMZ      1
# 8944   But the media s concerned Trump is the threat ...      1
# 441    Imagine being a woman going to a university wh...      1
# ...                                                  ...    ...
# 16850  Bouthaina Shaaban, Political & Media Advisor t...      1
# 6265   WHY IS THIS CRIMINAL ALLOWED TO JUST SKATE BY ...      1
# 11284  Obama has shown favoritism towards the Muslim ...      1
# 860    Tonight, Tucker Carlson took on Yvette Felarca...      1
# 15795  You can t make this up! Why are these criminal...      1
#
# [37067 rows x 3 columns]

# %%
real_news
# Out:
#                                                    title  \
# 20340  Two People Die after Eating Raw-Milk Cheese Ma...
# 27348  DUP blames Sinn Fein for Northern Ireland talk...
# 11114  Exclusive: Former top Brazil prosecutor says s...
# 23881  U.S. intelligence chief says Russia involvemen...
# 9561   Macri's coalition poised to win key Argentina ...
# ...                                                  ...
# 16850  NY Assembly speaker drives home priorities ahe...
# 6265   As Reproductive Rights Hang In The Balance, De...
# 11284  Report Accuses Facebook of Gender Bias Against...
# 860    2 Valedictorians in Texas Declare Undocumented...
# 15795  Limbaugh on Trump’s Shots at Freedom Caucus: T...
#
#                                                     text  label
# 20340  Two people have died following an outbreak of ...      0
# 27348  BELFAST (Reuters) - A senior member of Norther...      0
# 11114  BRASILIA (Reuters) - Three senior Brazilian la...      0
# 23881  WASHINGTON (Reuters) - U.S. Director of Nation...      0
# 9561   BUENOS AIRES (Reuters) - Argentine President M...      0
# ...                                                  ...    ...
# 16850  NEW YORK (Reuters) - New York’s top Democratic...      0
# 6265   WASHINGTON -- Forty-three years after the Supr...      0
# 11284  A newly published report has accused Facebook ...      0
# 860    When Mayte Lara Ibarra, the valedictorian of h...      0
# 15795  Friday on his nationally syndicated radio show...      0
#
# [35028 rows x 3 columns]

# %%
combined_news = pd.concat([fake_news, real_news])

# %%
combined_news.to_csv('combined.csv', index=False)

# %%
combined_news = pd.read_csv('combined.csv')

# %% [markdown]
# # Creating the Train, Test and Validation Sets
#
# The 80-20 split is pedagogically the best split but since we also have to create an additional validation set, it will technically be 80-10-10. This split is being done through train_test_split. It is paramount that if one instance of fake news appears in the training set, it doesn't appear in the validation and test set. This is to ensure that both the validation and test sets are truly "unseen" data in comparison to the training set but is still representative of the type of data that will be encountered by the model. The same holds for any data that appears in the validation and test set. The data has to be truly unique in terms of occurrence. Additional check to ensure this will be undertaken in the coming sections.

# %%
# Add a unique identifier column to combined_news DataFrame
combined_news['unique_id'] = range(len(combined_news))

# Define the percentages for splitting
train_percent = 0.8
val_percent = 0.1
test_percent = 0.1

# Group the data by the 'label' column
grouped = combined_news.groupby('label')

# Initialize empty DataFrames for train, validation, and test sets
train_data = pd.DataFrame(columns=combined_news.columns)
val_data = pd.DataFrame(columns=combined_news.columns)
test_data = pd.DataFrame(columns=combined_news.columns)

# Iterate over each label group
for label, group in grouped:
    # Split the group into train and remaining data
    train, remaining = train_test_split(group, train_size=train_percent, random_state=42)
    
    # Split the remaining data into validation and test sets
    val, test = train_test_split(remaining, test_size=0.5, random_state=42)
    
    # Append the splits to the respective DataFrames
    train_data = pd.concat([train_data, train])
    val_data = pd.concat([val_data, val])
    test_data = pd.concat([test_data, test])

# Reset the indices for the DataFrames
train_data.reset_index(drop=True, inplace=True)
val_data.reset_index(drop=True, inplace=True)
test_data.reset_index(drop=True, inplace=True)

# Save datasets to CSV files
train_data.to_csv('train.csv', index=False)
val_data.to_csv('val.csv', index=False)
test_data.to_csv('test.csv', index=False)

# %%
train_data
# Out:
#                                                    title  \
# 0      Trump Accused of ‘Environmental Racism’ in Wit...
# 1      Factbox: Where the bookies and trading exchang...
# 2      Chinese official calls Trump 'irrational' on t...
# 3      Factbox: Five facts about Mike Pence, Trump's ...
# 4      Mnangagwa told Mugabe he will be safe in Zimba...
# ...                                                  ...
# 57670  OBAMA’S ARROGANCE: WATCH As He Admonishes Repo...
# 57671                                         IV Varitas
# 57672  BLACK FEMALE DEMOCRAT ON HER SUPPORT FOR TRUMP...
# 57673  “They Will Kill Him Before They Let Him Become...
# 57674  ANTIFA BEWARE! BIKERS FOR TRUMP Makes Huge Ann...
#
#                                                     text label unique_id
# 0      In a   leap of reason, a several journals and ...     0     60151
# 1      NEW YORK (Reuters) - A Reuters/Ipsos tracking ...     0     55787
# 2      WASHINGTON (Reuters) - Chinese Finance Ministe...     0     66255
# 3      (Reuters) - Republican Donald Trump will name ...     0     46220
# 4      HARARE (Reuters) - Incoming Zimbabwe leader Em...     0     62789
# ...                                                  ...   ...       ...
# 57670  Being called out for his utter incompetence as...     1     16850
# 57671  Mail with questions or comments about this sit...     1      6265
# 57672  An Atlanta Democrat makes some very valid poin...     1     11284
# 57673  This letter was originally attributed to well-...     1       860
# 57674  BIKERS FOR TRUMP announced their support for P...     1     15795
#
# [57675 rows x 4 columns]

# %%
train_data.value_counts("label")
# Out:
# label
# 1    29653
# 0    28022
# dtype: int64

# %%
val_data
# Out:
#                                                   title  \
# 0     Turkey's Erdogan angers critics with plan to r...
# 1          Austin Schools Jump on ’Sanctuary’ Bandwagon
# 2               Why the way we pick our VPs is terrible
# 3     Trump unlikely to be able to renegotiate clima...
# 4     Key justice Kennedy wavers as Supreme Court co...
# ...                                                 ...
# 7205  Smart Meter Case Testimony Before the Pennsylv...
# 7206  CLOAKED IN CONSPIRACY: Overview of JFK Files R...
# 7207         Revolutions and Reforms: An Eroded Culture
# 7208  A Sick Little Boy Just Found a Heart Donor Hou...
# 7209  Why Everyone on Facebook Is Checking into Stan...
#
#                                                    text label unique_id
# 0     ISTANBUL (Reuters) - President Tayyip Erdogan ...     0     39429
# 1     In a special session held Monday evening, Aust...     0     49957
# 2     Mike Pence and Tim Kaine will take the stage f...     0     48566
# 3     COLOGNE (Reuters) - Donald Trump would be “hig...     0     56707
# 4     WASHINGTON (Reuters) - A closely divided Supre...     0     60961
# ...                                                 ...   ...       ...
# 7205  By Catherine J. Frompovich This is the continu...     1       127
# 7206  Shawn Helton 21st Century WireSince late Octob...     1     24891
# 7207  “Those who make peaceful revolution impossible...     1      2140
# 7208  First Lady Melania Trump has been busy praying...     1      5455
# 7209  Pin 1 \n( ANTIMEDIA ) When it comes to brute f...     1     20937
#
# [7210 rows x 4 columns]

# %%
val_data.value_counts("label")
# Out:
# label
# 1    3707
# 0    3503
# dtype: int64

# %%
test_data
# Out:
#                                                   title  \
# 0     Mexico Vows $50 Million Legal Fund to Fight U....
# 1     EU, U.S. high-level meeting on laptop ban to b...
# 2     In valedictory speech, Obama takes note of val...
# 3     Harold Hayes, Survivor of Secret World War II ...
# 4     Zimbabwe's Mugabe sacks VP seen as top success...
# ...                                                 ...
# 7205  “YOU’RE HIRED!” Trump Pulls Unemployed Vet Fro...
# 7206  Project Veritas 4: Robert Creamer's Illegal $2...
# 7207  LOL! FAKE INDIAN Elizabeth Warren Returns DNA ...
# 7208  Hollande set to lose French presidency after c...
# 7209                    Taking a Page from Joe McCarthy
#
#                                                    text label unique_id
# 0     MEXICO CITY (AP)  —   Mexico’s top diplomat sa...     0     58400
# 1     BRUSSELS (Reuters) - The European Union and th...     0     65393
# 2     ATHENS (Reuters) - President Barack Obama exto...     0     52740
# 3     Harold Hayes, the last surviving member of a b...     0     47619
# 4     HARARE (Reuters) - Zimbabwe s President Robert...     0     44991
# ...                                                 ...   ...       ...
# 7205  No matter which candidate you support, this mo...     1     10600
# 7206    Project Veritas 4: Robert Creamer's Illegal ...     1     22253
# 7207  In February, Boston-based entrepreneur and inv...     1      9192
# 7208  UK Express October 26, 2016 \nThe European lea...     1     27875
# 7209  Taking a Page from Joe McCarthy November 1, 20...     1     31387
#
# [7210 rows x 4 columns]

# %%
test_data.value_counts("label")
# Out:
# label
# 1    3707
# 0    3503
# dtype: int64

# %%
# Load the CSV files into DataFrames
train_data = pd.read_csv('train.csv')
val_data = pd.read_csv('val.csv')
test_data = pd.read_csv('test.csv')

# Get unique IDs for each dataset
train_unique_ids = set(train_data['unique_id'])
val_unique_ids = set(val_data['unique_id'])
test_unique_ids = set(test_data['unique_id'])

# Find unique IDs in train not in val or test
train_not_in_val = train_unique_ids - val_unique_ids
train_not_in_test = train_unique_ids - test_unique_ids

# Find unique IDs in val not in train or test
val_not_in_train = val_unique_ids - train_unique_ids
val_not_in_test = val_unique_ids - test_unique_ids

# Find unique IDs in test not in train or val
test_not_in_train = test_unique_ids - train_unique_ids
test_not_in_val = test_unique_ids - val_unique_ids

print(f"Rows in train_data: {len(train_data)}")
print(f"Rows in train_data not in val_data: {len(train_not_in_val)}")
print(f"Rows in train_data not in test_data: {len(train_not_in_test)}")
print("")

print(f"Rows in train_data: {len(val_data)}")
print(f"Rows in val_data not in train_data: {len(val_not_in_train)}")
print(f"Rows in val_data not in test_data: {len(val_not_in_test)}")
print("")

print(f"Rows in test_data: {len(test_data)}")
print(f"Rows in test_data not in train_data: {len(test_not_in_train)}")
print(f"Rows in test_data not in val_data: {len(test_not_in_val)}")
# Out:
# Rows in train_data: 57675
# Rows in train_data not in val_data: 57675
# Rows in train_data not in test_data: 57675
#
# Rows in train_data: 7210
# Rows in val_data not in train_data: 7210
# Rows in val_data not in test_data: 7210
#
# Rows in test_data: 7210
# Rows in test_data not in train_data: 7210
# Rows in test_data not in val_data: 7210

# %%
os.remove("combined.csv")

# %%
# Check overlap between train_data and val_data
overlap_train_val = len(set(train_data[['title','text']].apply(tuple, axis=1)).intersection(val_data[['title','text']].apply(tuple, axis=1)))
print(f"Overlap between train_data and val_data: {overlap_train_val} common texts")

# Check overlap between train_data and test_data
overlap_train_test = len(set(train_data[['title','text']].apply(tuple, axis=1)).intersection(test_data[['title','text']].apply(tuple, axis=1)))
print(f"Overlap between train_data and test_data: {overlap_train_test} common texts")

# Check overlap between val_data and test_data
overlap_val_test = len(set(val_data[['title','text']].apply(tuple, axis=1)).intersection(test_data[['title','text']].apply(tuple, axis=1)))
print(f"Overlap between val_data and test_data: {overlap_val_test} common texts")
# Out:
# Overlap between train_data and val_data: 1325 common texts
# Overlap between train_data and test_data: 1286 common texts
# Overlap between val_data and test_data: 167 common texts

# %%
duplicates_count = train_data.duplicated(subset=['text']).sum()
print(f"Number of duplicate entries in the 'text' column: {duplicates_count}")

duplicates_count = val_data.duplicated(subset=['text']).sum()
print(f"Number of duplicate entries in the 'text' column: {duplicates_count}")

duplicates_count = test_data.duplicated(subset=['text']).sum()
print(f"Number of duplicate entries in the 'text' column: {duplicates_count}")
# Out:
# Number of duplicate entries in the 'text' column: 6241
# Number of duplicate entries in the 'text' column: 195
# Number of duplicate entries in the 'text' column: 212
